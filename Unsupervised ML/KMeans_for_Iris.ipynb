# %%
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris = load_iris()

# %%
X = (iris.data)
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
# Visualizing

sns.scatterplot(x=X[:, 0], y=X[:, 2], c=y)
# Out:
# <Axes: >

# %%
# Scaling

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# optional dimensionality reduction using PCA 

from sklearn.decomposition import PCA

pca  = PCA(n_components=2)

pca_data = pca.fit_transform(X_scaled)

# %%
# Elbow methdod
wcss = []


for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(pca_data)
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1,11), y=wcss, marker='o')
# Out:
# <Axes: >

# %%
# Kmeans

kmeans = KMeans(
    n_clusters=3,
    random_state=10
)
labels = kmeans.fit_predict(pca_data)
sns.scatterplot(x=X[:, 0], y=X[:,1], c=labels)
sns.scatterplot(x=cluster_centers_[:, 0], y=cluster_centers_[:, 1], marker='*', color="red", s=200 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 9
#       7 labels = kmeans.fit_predict(pca_data)
#       8 sns.scatterplot(x=X[:, 0], y=X[:,1], c=labels)
# ----> 9 sns.scatterplot(x=cluster_centers_[:, 0], y=cluster_centers_[:, 1], marker='*', color="red", s=200 )
#
# NameError: name 'cluster_centers_' is not defined
