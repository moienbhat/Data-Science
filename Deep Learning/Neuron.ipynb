# %%
import torch
import torch.nn as nn

# %%
# input
torch.manual_seed(32)          # like random state
inputs = torch.tensor([1.0, 2.0, 3.0])

# %%
neuron = nn.Linear(in_features=3, out_features=1)

# %%
output = neuron(inputs)

# %%
output
# Out:
# tensor([-0.0604], grad_fn=<ViewBackward0>)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[ 0.4338, -0.2632, -0.0992]], requires_grad=True)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.3299], requires_grad=True)

# %%
# verify using formula
neuron.weight @ inputs + neuron.bias
# Out:
# tensor([-0.0604], grad_fn=<AddBackward0>)
